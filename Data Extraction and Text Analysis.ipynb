# %%
import pandas as pd

# %%
file =('Input.xlsx')
newData = pd.read_excel(file)
newData
# Out:
#      URL_ID                                                URL
# 0         1  https://insights.blackcoffer.com/how-is-login-...
# 1         2  https://insights.blackcoffer.com/how-does-ai-h...
# 2         3  https://insights.blackcoffer.com/ai-and-its-im...
# 3         4  https://insights.blackcoffer.com/how-do-deep-l...
# 4         5  https://insights.blackcoffer.com/how-artificia...
# ..      ...                                                ...
# 165     167  https://insights.blackcoffer.com/role-big-data...
# 166     168  https://insights.blackcoffer.com/sales-forecas...
# 167     169  https://insights.blackcoffer.com/detect-data-e...
# 168     170  https://insights.blackcoffer.com/data-exfiltra...
# 169     171  https://insights.blackcoffer.com/impacts-of-co...
#
# [170 rows x 2 columns]

# %%
# importing the modules
import requests
from bs4 import BeautifulSoup

# %%
for index, row in newData.iterrows():
    print(row['URL_ID'], row[ 'URL'])
    # making requests instance
    reqs = requests.get(row[ 'URL'])

    # using the BeautifulSoup module
    soup = BeautifulSoup(reqs.text, 'html.parser')
    text = soup.get_text()
    print(text)
    title = soup.find_all('title')[0]
    print(title.get_text())
# Out:
# 1 https://insights.blackcoffer.com/how-is-login-logout-time-tracking-for-employees-in-office-done-by-ai/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 2 https://insights.blackcoffer.com/how-does-ai-help-to-monitor-retail-shelf-watches/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 3 https://insights.blackcoffer.com/ai-and-its-impact-on-the-fashion-industry/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 4 https://insights.blackcoffer.com/how-do-deep-learning-models-predict-old-and-new-drugs-that-are-successfully-treated-in-healthcare/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 5 https://insights.blackcoffer.com/how-artificial-intelligence-can-boost-your-productivity-level/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 6 https://insights.blackcoffer.com/how-are-genetic-sequencing-maps-affected-by-deep-learning-and-ai/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 7 https://insights.blackcoffer.com/how-is-ai-used-to-solve-traffic-management/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 8 https://insights.blackcoffer.com/benefits-of-big-data-in-different-fields/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 9 https://insights.blackcoffer.com/how-big-data-will-impact-the-future-of-business/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 10 https://insights.blackcoffer.com/how-will-ai-make-decisions-in-tomorrows-wars/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 11 https://insights.blackcoffer.com/which-one-is-better-ai-or-big-data/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 12 https://insights.blackcoffer.com/how-robots-can-help-in-e-learning-platforms/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 13 https://insights.blackcoffer.com/how-does-big-data-help-in-finance-and-the-growth-of-large-firms/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 14 https://insights.blackcoffer.com/future-of-work-robot-ai-and-automation/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 15 https://insights.blackcoffer.com/how-ai-will-help-the-defense-power-of-a-country/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 16 https://insights.blackcoffer.com/future-of-ai-and-machine-roles-in-the-medical-sector/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 17 https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 18 https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 19 https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 20 https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 21 https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 22 https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 23 https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 24 https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 25 https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 26 https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 27 https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 28 https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 29 https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 30 https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 31 https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 32 https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 33 https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 34 https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 35 https://insights.blackcoffer.com/evolution-of-advertising-industry/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 36 https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 37 https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 38 https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 39 https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 40 https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 41 https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 42 https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 43 https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 45 https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 46 https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 47 https://insights.blackcoffer.com/how-we-forecast-future-technologies/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 48 https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/
# Not Acceptable!Not Acceptable!An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Not Acceptable!
# 49 https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-3db807b33433> in <module>
#       2     print(row['URL_ID'], row[ 'URL'])
#       3     # making requests instance
# ----> 4     reqs = requests.get(row[ 'URL'])
#       5
#       6     # using the BeautifulSoup module
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     850         # Force connect early to allow us to validate the connection.
#     851         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 852             conn.connect()
#     853
#     854         if not conn.is_verified:
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     296     def connect(self):
#     297         # Add certificate verification
# --> 298         conn = self._new_conn()
#     299
#     300         hostname = self.host
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     142         try:
#     143             conn = connection.create_connection(
# --> 144                 (self.host, self.port), self.timeout, **extra_kw)
#     145
#     146         except SocketTimeout:
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %%
import urllib.request

url = "https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/"

resp = requests.get(url)
print(resp.status_code) # 200
print(resp.content)
# Out:
# 406
# b'<head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body></html>'
